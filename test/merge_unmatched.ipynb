# %%
import pandas as pd


hard_match_result = pd.read_csv("/Users/xuhaoshuai/Project/HumanIE-IPM-experiment-2.0/relation_data/brother/5_match_result/hard_match/1.csv", index_col='sent_id', usecols=['entity1', 'entity2', 'sent', 'processed_sent', 'label', 'hard_match'])
soft_match_result = pd.read_csv("/Users/xuhaoshuai/Project/HumanIE-IPM-experiment-2.0/relation_data/brother/5_match_result/soft_match/1.csv", index_col='sent_id', usecols=['entity1', 'entity2', 'sent', 'processed_sent', 'label', 'soft_match'])

# %%
hard_unmatched = hard_match_result[hard_match_result['hard_match'] == 0]
soft_unmatched = soft_match_result[soft_match_result['soft_match'] == 0]

# %%
hard_unmatched = hard_unmatched[['entity1', 'entity2', 'sent', 'processed_sent', 'label']]
soft_unmatched = soft_unmatched[['entity1', 'entity2', 'sent', 'processed_sent', 'label']]

# %%
result = pd.concat([hard_unmatched, soft_unmatched])
result
# Out:
#                      entity1 entity2  \
# sent_id
# TRAIN_SENT_ID_249528      李蔡      李广
# TRAIN_SENT_ID_249529      李蔡      李广
# TRAIN_SENT_ID_249532      李蔡      李广
# TRAIN_SENT_ID_249534      李蔡      李广
# TRAIN_SENT_ID_249537      李蔡      李广
# ...                      ...     ...
# TRAIN_SENT_ID_273135     包道乙      郑彪
# TRAIN_SENT_ID_275650     梁子鹏     李小龙
# TRAIN_SENT_ID_276236     张阿生      郭靖
# TRAIN_SENT_ID_277509     曾书书     王细雨
# TRAIN_SENT_ID_278845      于海     李连杰
#
#                                                                    sent  \
# sent_id
# TRAIN_SENT_ID_249528  如果 历史 是 残酷 的 ， 那么 霍去病 和 李广 、 李蔡 将军 一样 ， 不是 死 于...
# TRAIN_SENT_ID_249529  而 他 的 堂兄弟 李蔡 才能 不如 他 却 官至 丞相 ， 古人 认为 奇数 不 吉利 ，...
# TRAIN_SENT_ID_249532  班固 说 ： “ 山东 出相 ， 山西 出 将 ， 汉兴 ， 成纪 李广 、 李蔡 ， 上 ...
# TRAIN_SENT_ID_249534  《 史记 . 李将军 列传 》 《 李广 传 》 均 称 ： 其 从弟 李蔡 被 “ 封 为...
# TRAIN_SENT_ID_249537         2 、 “ 李蔡 ” 两句 ： 言 李广 虽 功勋卓著 ， 却终 无 封侯之 赏 。
# ...
